# %%
# %pip install tensorflow pandas numpy scikit-learn
# Out:
# Requirement already satisfied: tensorflow in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (2.16.2)
# Requirement already satisfied: pandas in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (2.3.3)
# Requirement already satisfied: numpy in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (1.26.4)
# Requirement already satisfied: scikit-learn in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (1.8.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: libclang>=13.0.0 in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from tensorflow) (4.25.8)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from tensorflow) (3.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from tensorflow) (3.12.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Requirement already satisfied: markdown>=2.6.8 in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.10)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.10.0 in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.3.0 in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from keras>=3.0.0->tensorflow) (14.2.0)
# Requirement already satisfied: namex in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from keras>=3.0.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from keras>=3.0.0->tensorflow) (0.18.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from rich->keras>=3.0.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from rich->keras>=3.0.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/sahibchouhan/Developer/Development/ml-env/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow) (0.1.2)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import pickle
import os

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense

# %%
data = pd.read_csv("data/Translation Dataset 10000.csv")
data.head()
# Out:
#   source_lang target_lang       source_text               target_text
# 0          en          ja         Thank you                ありがとうございます
# 1          hi          pa  यह मेरी किताब है          ਇਹ ਮੇਰੀ ਕਿਤਾਬ ਹੈ
# 2          en          hi       How are you               आप कैसे हैं
# 3          en          ja       I need help                   助けが必要です
# 4          ja          te    私はプログラミングが好きです  నాకు ప్రోగ్రామింగ్ ఇష్టం

# %%
data["input_text"] = (
    data["source_lang"] + " " +
    data["target_lang"] + " " +
    data["source_text"]
)

data["target_text"] = data["target_text"]
data[["input_text", "target_text"]].head()
# Out:
#                input_text               target_text
# 0         en ja Thank you                ありがとうございます
# 1  hi pa यह मेरी किताब है          ਇਹ ਮੇਰੀ ਕਿਤਾਬ ਹੈ
# 2       en hi How are you               आप कैसे हैं
# 3       en ja I need help                   助けが必要です
# 4    ja te 私はプログラミングが好きです  నాకు ప్రోగ్రామింగ్ ఇష్టం

# %%
tokenizer = Tokenizer(char_level=True)
tokenizer.fit_on_texts(
    data["input_text"].tolist() +
    data["target_text"].tolist()
)

VOCAB_SIZE = len(tokenizer.word_index) + 1
MAX_LEN = 40

VOCAB_SIZE
# Out:
# 163

# %%
encoder_input = tokenizer.texts_to_sequences(data["input_text"])
decoder_output = tokenizer.texts_to_sequences(data["target_text"])

encoder_input = pad_sequences(
    encoder_input, maxlen=MAX_LEN, padding="post"
)

decoder_output = pad_sequences(
    decoder_output, maxlen=MAX_LEN, padding="post"
)

decoder_output = np.expand_dims(decoder_output, -1)

# %%
encoder_inputs = Input(shape=(MAX_LEN,))
enc_emb = Embedding(VOCAB_SIZE, 64)(encoder_inputs)

encoder_lstm = LSTM(128, return_state=True)
_, state_h, state_c = encoder_lstm(enc_emb)

# %%
decoder_inputs = Input(shape=(MAX_LEN,))
dec_emb = Embedding(VOCAB_SIZE, 64)(decoder_inputs)

decoder_lstm = LSTM(128, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(
    dec_emb, initial_state=[state_h, state_c]
)

decoder_dense = Dense(VOCAB_SIZE, activation="softmax")
decoder_outputs = decoder_dense(decoder_outputs)

# %%
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy"
)

model.fit(
    [encoder_input, encoder_input],
    decoder_output,
    epochs=100,
    batch_size=8
)
# Out:
# Epoch 1/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 1.1866
# Epoch 2/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.6525
# Epoch 3/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4975
# Epoch 4/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4500
# Epoch 5/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4363
# Epoch 6/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4332
# Epoch 7/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4284
# Epoch 8/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4271
# Epoch 9/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4268
# Epoch 10/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4254
# Epoch 11/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4248
# Epoch 12/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4245
# Epoch 13/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4242
# Epoch 14/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4238
# Epoch 15/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4235
# Epoch 16/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4243
# Epoch 17/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4228
# Epoch 18/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4226
# Epoch 19/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4225
# Epoch 20/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4225
# Epoch 21/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4227
# Epoch 22/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4229
# Epoch 23/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4223
# Epoch 24/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4222
# Epoch 25/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 36s 29ms/step - loss: 0.4217
# Epoch 26/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4219
# Epoch 27/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4219
# Epoch 28/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4217
# Epoch 29/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4219
# Epoch 30/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4216
# Epoch 31/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4213
# Epoch 32/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4217
# Epoch 33/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 36s 29ms/step - loss: 0.4214
# Epoch 34/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 0.4212
# Epoch 35/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 28s 22ms/step - loss: 0.4215
# Epoch 36/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 52s 41ms/step - loss: 0.4212
# Epoch 37/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4211
# Epoch 38/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4221
# Epoch 39/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4212
# Epoch 40/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 100s 80ms/step - loss: 0.4210
# Epoch 41/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4213
# Epoch 42/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4208
# Epoch 43/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4211
# Epoch 44/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 101s 81ms/step - loss: 0.4210
# Epoch 45/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4211
# Epoch 46/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4208
# Epoch 47/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4208
# Epoch 48/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4218
# Epoch 49/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 413s 330ms/step - loss: 0.4210
# Epoch 50/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 175s 140ms/step - loss: 0.4207
# Epoch 51/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4210
# Epoch 52/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4207
# Epoch 53/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4207
# Epoch 54/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 188s 151ms/step - loss: 0.4204
# Epoch 55/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4207
# Epoch 56/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4205
# Epoch 57/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4207
# Epoch 58/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 44s 35ms/step - loss: 0.4206
# Epoch 59/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 18s 15ms/step - loss: 0.4205
# Epoch 60/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4211
# Epoch 61/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 18s 15ms/step - loss: 0.4205
# Epoch 62/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4207
# Epoch 63/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4206
# Epoch 64/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4206
# Epoch 65/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4204
# Epoch 66/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4205
# Epoch 67/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4205
# Epoch 68/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4206
# Epoch 69/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4204
# Epoch 70/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4206
# Epoch 71/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4213
# Epoch 72/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 54s 15ms/step - loss: 0.4204
# Epoch 73/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4204
# Epoch 74/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4205
# Epoch 75/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4203
# Epoch 76/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 22s 18ms/step - loss: 0.4206
# Epoch 77/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4204
# Epoch 78/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 0.4209
# Epoch 79/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4203
# Epoch 80/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4204
# Epoch 81/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4203
# Epoch 82/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 0.4202
# Epoch 83/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4204
# Epoch 84/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4205
# Epoch 85/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4203
# Epoch 86/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4201
# Epoch 87/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4204
# Epoch 88/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4200
# Epoch 89/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4203
# Epoch 90/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4203
# Epoch 91/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4204
# Epoch 92/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4208
# Epoch 93/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4203
# Epoch 94/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4202
# Epoch 95/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4205
# Epoch 96/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4201
# Epoch 97/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4202
# Epoch 98/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4206
# Epoch 99/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4203
# Epoch 100/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 16ms/step - loss: 0.4202

# %%
os.makedirs("model", exist_ok=True)

model.save("model/translation_model.h5")

with open("model/tokenizer.pkl", "wb") as f:
    pickle.dump(tokenizer, f)

print("Model and tokenizer saved successfully")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model and tokenizer saved successfully
